# %%
import os

with open("pflanzen_arten_madagascar", encoding="utf-8") as f1, open("pflanzen_arten_mauritius", encoding="utf-8") as f2:
    lines1 = f1.readlines()
    lines2 = f2.readlines()

row1 = [line.strip() for line in lines1]
row2 = [line.strip() for line in lines2]

if len(row1) != len(row2):
    while len(row1) < len(row2):
        row1.append("")  # Füge leere Zeilen hinzu, um die Längen auszugleichen
    while len(row2) < len(row1):
        row2.append("")

count = 0
place1 = 0

for l1 in row1:
    place1 += 1
    place2 = 0
    for l2 in row2:
        place2 += 1
        if l1 == l2 and l1 != "":
            count += 1
            print(f"Gleiche Namen in Zeile {place1} von \"pflanzen_arten_madagascar\" und Zeile {place2} von \"pflanzen_arten_mauritius\": {l1}")
#    if l1 != l2:
#        print(f"Achso {i} ist: {l1.strip()} UND {l2.strip()}")
#    if l1 == l2:
#        print(f"Gleich in Zeile {i}: {l1.strip()}")
#        count += 1

print("Soviele Pflanzen sind gleich:", count)

#Programm merkt nicht wenn die Pflanzen nicht in der selben Zeile sind
#
#Lösungsidee:
# Out:
# Gleiche Namen in Zeile 2 von "pflanzen_arten_madagascar" und Zeile 2 von "pflanzen_arten_mauritius": Ravenala
# Gleiche Namen in Zeile 5 von "pflanzen_arten_madagascar" und Zeile 6 von "pflanzen_arten_mauritius": Mangifera indica
# Soviele Pflanzen sind gleich: 2
